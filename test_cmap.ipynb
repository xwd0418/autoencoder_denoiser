# %%
import matplotlib.image
import numpy as np
import matplotlib.pyplot as plt

im = np.random.choice([0,1,10], size=(90, 90), p=[0.5,0.3,0.2])

im2 = im/10.
clist = [(0,"white"), (1./10.,"green"), (1, "red")]
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("name", clist)
matplotlib.image.imsave('cmap_sample'+'.png', im, cmap=cmap)
plt.imshow(im, cmap=cmap)

# %%
def id (x):
    return x
im = np.random.choice([0,1,10], size=(90, 90), p=[0.5,0.5,0.0])

im2 = np.zeros((90,90))
im2[0:10] += 0.1
clist = [(0,"white"), (1./10.,"green"), (1, "red")]
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("name", clist)
# matplotlib.image.imsave(__file__+'.png', im, cmap=cmap)
difference = im2
plt.imshow(difference, cmap = cmap, vmax=0.1, vmin=np.min(difference))
matplotlib.image.imsave('cmap_sample'+'.png', im2, cmap=cmap)
